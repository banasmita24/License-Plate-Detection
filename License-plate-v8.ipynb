# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.5/974.5 kB 23.8 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.1 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.5 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
# ...

# %%
dataset_yaml = """path: /kaggle/input/ccpd-dataset/ccpd  # Update this path
train: images/train
val: images/val
test: images/test

nc: 1  # Number of classes (1 for license plates)
names: ['license_plate']
"""

# Save the YAML file in the current working directory
with open("dataset.yaml", "w") as file:
    file.write(dataset_yaml)

print("✅ dataset.yaml file created successfully!")
# Out:
# ✅ dataset.yaml file created successfully!

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.yaml")  

model.train(data="/kaggle/working/dataset.yaml", epochs=50, imgsz=640, batch=32)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.107 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/working/runs/detect/train/weights/last.pt")

model.train(data="/kaggle/working/dataset.yaml", epochs=50, imgsz=640, batch=32, resume=True)
# Out:
# Ultralytics 8.3.107 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !zip -r results.zip /kaggle/working
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/results_manual.png (deflated 14%)
#   adding: kaggle/working/dataset.yaml (deflated 28%)
#   adding: kaggle/working/runs.zip (stored 0%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/custom_results.png (deflated 21%)
#   adding: kaggle/working/runs0.zip (stored 0%)
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/val2/ (stored 0%)
#   adding: kaggle/working/runs/detect/val2/confusion_matrix.png (deflated 36%)
#   adding: kaggle/working/runs/detect/val2/val_batch2_pred.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/val2/val_batch2_labels.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/val2/PR_curve.png (deflated 29%)
#   adding: kaggle/working/runs/detect/val2/val_batch0_pred.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/val2/val_batch1_pred.jpg (deflated 6%)
# ...

# %%
from IPython.display import FileLink
FileLink(r'results.zip')
# Out:
# /kaggle/working/results.zip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and clean
df = pd.read_csv("runs/detect/train/results.csv")
df.columns = df.columns.str.strip()

epochs = range(1, len(df) + 1)

plt.figure(figsize=(16, 10))

# 🔹 1. Training loss
plt.subplot(2, 2, 1)
plt.plot(epochs, df['train/box_loss'], label='Box Loss')
plt.plot(epochs, df['train/cls_loss'], label='Class Loss')
plt.plot(epochs, df['train/dfl_loss'], label='DFL Loss')
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# 🔹 2. mAP
plt.subplot(2, 2, 2)
plt.plot(epochs, df['metrics/mAP50(B)'], label='mAP@0.5')
plt.plot(epochs, df['metrics/mAP50-95(B)'], label='mAP@0.5:0.95')
plt.title("Mean Average Precision (Val)")
plt.xlabel("Epoch")
plt.ylabel("mAP")
plt.legend()

# 🔹 3. Precision
plt.subplot(2, 2, 3)
plt.plot(epochs, df['metrics/precision(B)'], label='Precision')
plt.title("Validation Precision")
plt.xlabel("Epoch")
plt.ylabel("Precision")
plt.legend()

# 🔹 4. Recall
plt.subplot(2, 2, 4)
plt.plot(epochs, df['metrics/recall(B)'], label='Recall')
plt.title("Validation Recall")
plt.xlabel("Epoch")
plt.ylabel("Recall")
plt.legend()

plt.tight_layout()
plt.savefig("results_manual.png")
print("✅ Saved graph as results_manual.png")
plt.show()
# Out:
# ✅ Saved graph as results_manual.png

# %%
# !yolo val model=/kaggle/working/runs/detect/train/weights/best.pt data=/kaggle/working/dataset.yaml split=test
# Out:
# Ultralytics 8.3.107 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv8n summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/input/ccpd-dataset/ccpd/labels/test... 100579 images, 0 ba
# val: WARNING ⚠️ Cache directory /kaggle/input/ccpd-dataset/ccpd/labels is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all     100579     100579      0.987      0.989      0.992      0.646
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Speed: 0.1ms preprocess, 1.4ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val
